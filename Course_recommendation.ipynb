# %%
import json

# %%
  
# Opening JSON file 
f = open('students.json',encoding='utf8') 
  
# returns JSON object as  
# a dictionary 
data = json.load(f) 
  
# Iterating through the json 
# list 
#for dat in data:
#    print(dat)
#   print(type(dat))
  
# Closing file 
f.close()

# %%
students=pd.DataFrame(data)
students.head()
# Out:
#                                 sid  \
# 0  6e6dabfe6d4eaa2d15b4672e0d0fad5a
# 1  a4839004275f9f0583a20f03a8b759c3
# 2  bd73581ef03a1f15f24a7d2c7b573792
# 3  7a3595d03ba05f3778ade4e0881be40f
# 4  ee2dce155a659d3b6594479d228e98b8
#
#                                  target_super_groups  \
# 0  [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168', '...
# 1  [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168', '...
# 2  [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168', '...
# 3  [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168', '...
# 4  [{'_id': 'c1d47cdfe41a7ea2c337dd54c5114168', '...
#
#                                              targets
# 0  [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba', '...
# 1  [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba', '...
# 2  [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba', '...
# 3  [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba', '...
# 4  [{'_id': '7a5d8c4c00f5f6340f28ba4b49e519ba', '...

# %%
enrollments=pd.read_json('course_enrollments.json')
enrollments.head()
# Out:
#                                     enrolled_courses  \
# 0                 [c64ca44849ae86093254a01b5748466f]
# 1                 [c64ca44849ae86093254a01b5748466f]
# 2                 [c64ca44849ae86093254a01b5748466f]
# 3                 [c64ca44849ae86093254a01b5748466f]
# 4  [e2e15f7b9ea0df0fbab2d5c6929a894e, c64ca44849a...
#
#                          studentIds
# 0  6e6dabfe6d4eaa2d15b4672e0d0fad5a
# 1  a4839004275f9f0583a20f03a8b759c3
# 2  bd73581ef03a1f15f24a7d2c7b573792
# 3  7a3595d03ba05f3778ade4e0881be40f
# 4  ee2dce155a659d3b6594479d228e98b8

# %%
submissions=pd.read_json('test_submissions.json')
submissions.head()
# Out:
#    correct            created_on  marks  partial  skipped  \
# 0        0  0001-01-01T00:00:00Z  -1.50        0        4
# 1        2  0001-01-01T00:00:00Z   0.50        0        2
# 2        1  0001-01-01T00:00:00Z   0.75        0        8
# 3        0  0001-01-01T00:00:00Z  -0.75        0        7
# 4        8  0001-01-01T00:00:00Z   1.00        0       39
#
#                           studentId                            testId  \
# 0  15124e459c173f28a53b4863fdb8f6b3  dcf403b70447d14bdfc2a922452abddd
# 1  15124e459c173f28a53b4863fdb8f6b3  a82e3ddc77d28b3ef773e1228dd13d12
# 2  dd3fb5b38d49c87597f46c9e390286de  dcf403b70447d14bdfc2a922452abddd
# 3  dd3fb5b38d49c87597f46c9e390286de  9396e6f8e26238f13cd803cc3210b5b0
# 4  c883aca5dc77e2bca2042203cf6d4a47  88015babd0ce62e05581f9d07c4b5ca9
#
#    time_taken  total_answered  wrong
# 0          21               6      6
# 1          11               8      6
# 2          18               2      1
# 3           5               3      3
# ...

# %%
test_details=pd.read_json('tests_details.json')
test_details.head()
# Out:
#                                               target target_super_group  \
# 0  [{'_id': 'ce93e65e281ffed2347769d363c25b70', '...               None
# 1                                               None               None
# 2                                               None               None
# 3  [{'_id': '774732a9be9cd1f7681f7eb699d3bdf8', '...               None
# 4  [{'_id': '6ac844c11e30c46f4b9583c85653d610', '...               None
#
#                             test_id
# 0  b4ca204631b17b6b486c361872fd2af2
# 1  b25b5a4ec5c9ed9cbf8c1b2dbce2e5ec
# 2  4f6de001762ca3cb6546de31962ad917
# 3  a5509829b0acbc147323aaf75e8ea73e
# 4  7bcbc0211f63141908bd2f0bb44d1bdd

# %%
class_details = pd.read_csv (r'class_details.csv')   #read the csv file (put 'r' before the path string to address any special characters in the path, such as '\'). Don't forget to put the file name at the end of the path + ".csv"
print(class_details)
# Out:
#                                test_id                       target___id  \
# 0     8f9a4bd57683734c52897423dd741ede  01e1502c5eec9236f4531c634b35031c
# 1     4aad8b59ca5b690bc2eff371fec2f83e  01e1502c5eec9236f4531c634b35031c
# 2     7aac7e033c88241a87eb43cf66fb9704  01e1502c5eec9236f4531c634b35031c
# 3     305071c5117adc971a6f928f36b0268e  01e1502c5eec9236f4531c634b35031c
# 4     354cea9d7b43be07ccdb7920634ad604  065c0dc33eddd1263fc57eefa310365b
# 5     edd9eaa9ff832169b712f4c3967e156b  065c0dc33eddd1263fc57eefa310365b
# 6     49b1eda4e080da8247cfb130acd9bebf  065c0dc33eddd1263fc57eefa310365b
# 7     2164992435d870a8704f4b3f4888e26d  065c0dc33eddd1263fc57eefa310365b
# 8     ccca1f430ca1fb71c389f3214c76de63  065c0dc33eddd1263fc57eefa310365b
# 9     932b1625a65e5722076c706c515d7182  065c0dc33eddd1263fc57eefa310365b
# 10    7e554dd94212318afedbaa0a8ef2a0b3  065c0dc33eddd1263fc57eefa310365b
# 11    74cc4247a45cda8dcd9341064b444f6c  065c0dc33eddd1263fc57eefa310365b
# ...

# %%
class_details.head()
# Out:
#                             test_id                       target___id  \
# 0  8f9a4bd57683734c52897423dd741ede  01e1502c5eec9236f4531c634b35031c
# 1  4aad8b59ca5b690bc2eff371fec2f83e  01e1502c5eec9236f4531c634b35031c
# 2  7aac7e033c88241a87eb43cf66fb9704  01e1502c5eec9236f4531c634b35031c
# 3  305071c5117adc971a6f928f36b0268e  01e1502c5eec9236f4531c634b35031c
# 4  354cea9d7b43be07ccdb7920634ad604  065c0dc33eddd1263fc57eefa310365b
#
#   target__title__language    target__title__value target__isPrimary  \
# 0                 English              Bihar STET              True
# 1                 English              Bihar STET              True
# 2                 English              Bihar STET              True
# 3                 English              Bihar STET              True
# 4                 English  Bihar Police ASI Steno              True
#
#    target_super_group  target    | |___id |__title__language |__title__value  \
# ...
